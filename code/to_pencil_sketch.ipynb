# %%
from sketch import pencil_sketch_from_bgr
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from sketch import pencil_sketch_from_bgr
#
# ImportError: cannot import name 'pencil_sketch_from_bgr' from 'sketch' (/home/jovyan/work/Image-to-Pencil-Sketch/code/sketch.py)
